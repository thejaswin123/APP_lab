# %% [markdown]
# # Tinker practice programs
# **Done by:
# <br>Thejaswin.S
# <br>RA1911026010029
# <br>CSE-AIML K1**

# %% [markdown]
# **Using label widgets**

# %%
import tkinter as tk
root=tk.Tk()
label=tk.Label(root,text="hello world")
label.grid()
root.mainloop()

# %%
from IPython.display import Image
Image(filename='1.png')

# %% [markdown]
# **Sample program**

# %%
import tkinter as tk
from tkinter import messagebox
root=tk.Tk()
def helloCallBack():
    msg = messagebox.showinfo( "hello", "closing...")
    root.destroy()
root.title("thejaswin")
root.geometry("500x400")
label=tk.Label(root,text="hello world",font=("calibri",40),bg="red",fg="yellow",width='100',height='200')
label.pack()
button=tk.Button(root,text="stop",fg='white',bg='green',width='10',height='3',command=helloCallBack)
button.place(x=200,y=300)
root.mainloop()

# %%
from IPython.display import Image
Image(filename='2.png')

# %% [markdown]
# **Using Button widget**

# %%
import tkinter as tk
root = tk.Tk()
button = tk.Button(root, text='Stop', width=25, command=root.destroy)
button.pack()
root.mainloop()

# %%
from IPython.display import Image
Image(filename='3.png')

# %%
import tkinter as tk
r = tk.Tk()
r.title('Counting Seconds')
button = tk.Button(r, text='Stop', width=25, command=r.destroy)
button.pack()
r.mainloop()

# %%
import tkinter as tk
from tkinter import messagebox
def hello():
    msg = messagebox.showinfo( "GUI Event Demo","Button Demo")
root = tk.Tk()
root.geometry("200x200")
b = tk.Button(root, text='Fire Me',command=hello)
b.place(x=50,y=50)
root.mainloop()

# %%
from IPython.display import Image
Image(filename='4.png')

# %% [markdown]
# **Using entry widget**

# %%
def hello():
    msg = messagebox.showinfo( "GUI Event Demo",t.get())
root = tk.Tk()
root.geometry("200x200")
l1=tk.Label(root,text="Name:")
l1.grid(row=0)
t=tk.Entry(root)
t.grid(row=0,column=1)
b = tk.Button(root, text='Fire Me',command=hello)
b.grid(row=1,columnspan=2);
root.mainloop()

# %%
from IPython.display import Image
Image(filename='5.png')

# %% [markdown]
# **Using canvas**

# %%
from tkinter import *
master = Tk()
w = Canvas(master, width=40, height=60)
w.pack()
canvas_height=20
canvas_width=200
y = int(canvas_height / 2)
w.create_line(0, y, canvas_width, y )
mainloop()

# %%
from IPython.display import Image
Image(filename='6.png')

# %%
from tkinter import *
from tkinter import messagebox
top = Tk()
C = Canvas(top, bg = "blue", height = 250, width = 300)
coord = 10, 50, 240, 210
arc = C.create_arc(coord, start = 0, extent = 150, fill = "red")
line = C.create_line(10,10,200,200,fill = 'white')
C.pack()
top.mainloop()

# %%
from IPython.display import Image
Image(filename='7.png')

# %% [markdown]
# **Using check button**

# %%
def test():
    if(v1.get()==1 ):
        v2.set(0)
        print("Male")
    if(v2.get()==1):
        v1.set(0)
        print("Female")

from tkinter import *
root= Tk()
root.title('Checkbutton Demo')
v1=IntVar()
v2=IntVar()
cb1=Checkbutton(root,text='Male', variable=v1,onvalue=1, offvalue=0, command=test)
cb1.grid(row=0)
cb2=Checkbutton(root,text='Female', variable=v2,onvalue=1, offvalue=0, command=test)
cb2.grid(row=1)
root.mainloop()
# Out:
# Male
# Female
# Male

# %%
from IPython.display import Image
Image(filename='8.png')

# %% [markdown]
# **Using radiobutton**

# %%
def choice():
    if(radio.get()==1):
        root.configure(background='red')
    elif(radio.get()==2):
        root.configure(background='blue')
    elif(radio.get()==3):
        root.configure(background='green')
root= Tk()
root.geometry("200x200")
radio=IntVar()
rb1=Radiobutton(root,text='Red', variable=radio,width=25,value=1, command=choice)
rb1.grid(row=0)
rb2=Radiobutton(root,text='Blue', variable=radio,width=25,value=2, command=choice)
rb2.grid(row=1)
rb3=Radiobutton(root,text='Green', variable=radio,width=25,value=3, command=choice)
rb3.grid(row=3)
root.mainloop()

# %%
from IPython.display import Image
Image(filename='9.png')

# %% [markdown]
# **Using scale widget**

# %%
from tkinter import messagebox
root= Tk()
root.title('Scale Demo')
root.geometry("200x200")
def slide():
    msg = messagebox.showinfo( "GUI Event Demo",v.get())
v = DoubleVar()
scale = Scale( root, variable = v, from_ = 1, to = 50, orient = HORIZONTAL)
scale.pack(anchor=CENTER)
btn = Button(root, text="Value", command=slide)
btn.pack(anchor=CENTER)
root.mainloop()

# %%
from IPython.display import Image
Image(filename='10.png')

# %% [markdown]
# **Using spinbox widget**

# %%
from tkinter import *
from tkinter import messagebox
root= Tk()
root.title('Scale Demo')
root.geometry("200x200")
def slide():
    msg = messagebox.showinfo( "SpinBox Event Demo",spin.get())
spin = Spinbox(root, from_= 0, to = 25)
spin.pack(anchor=CENTER)
btn = Button(root, text="Value", command=slide)
btn.pack(anchor=CENTER)
root.mainloop()

# %%
from IPython.display import Image
Image(filename='11.png')

# %% [markdown]
# **Using menubutton**

# %%
from tkinter import *
from tkinter import messagebox
root= Tk()
root.title('Scale Demo')
root.geometry("200x200")
menubutton = Menubutton(root, text = "File", relief = FLAT)
menubutton.grid()
menubutton.menu = Menu(menubutton)
menubutton["menu"]=menubutton.menu
menubutton.menu.add_checkbutton(label = "New", variable=IntVar(),command='new')
menubutton.menu.add_checkbutton(label = "Open", variable = IntVar())
menubutton.pack()
root.mainloop()

# %%
from IPython.display import Image
Image(filename='12.png')

# %%
from tkinter import *
from tkinter import messagebox
root= Tk()
root.title('Menu Demo')
root.geometry("200x200")
def new():
    print("New Menu!")
def disp():
    print("Open Menu!")
menubutton = Menubutton(root, text="File")
menubutton.grid()
menubutton.menu = Menu(menubutton, tearoff = 0)
menubutton["menu"] = menubutton.menu
menubutton.menu.add_command(label="Createnew",command=new)
menubutton.menu.add_command(label="Open",command=disp)
menubutton.menu.add_separator()
menubutton.menu.add_command(label="Exit",command=root.quit)
menubutton.pack()
root.mainloop()
# Out:
# New Menu!
# Open Menu!

# %%
from IPython.display import Image
Image(filename='13.png')
